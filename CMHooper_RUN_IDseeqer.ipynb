# %% [markdown]
# # Running IDseeqer

# %%
#Don't forget to adjust the settings

# %%
# !python settings.py

# %%
# !python IDseeqer.py
# Out:
# >>> Searching Item 1 out of 11844.
# > Will now search Uniprot
# failed for: MLOC_55142.1 undefined entity: line 35, column 1431
# >> Not found in Uniprot, will now search NCBI_PROT
# failed for: MLOC_55142.1 No records found in handle
# >>> Not found in NCBI_PROT, will now search gramene
# failed for: MLOC_55142.1 No records found in handle
# >>> Not found in gramene, will now search RAP
# failed for: MLOC_55142.1 list index out of range
#
# >>> Searching Item 2 out of 11844.
# > Will now search Uniprot
# failed for: MLOC_12359.2 undefined entity: line 35, column 1431
# >> Not found in Uniprot, will now search NCBI_PROT
# failed for: MLOC_12359.2 No records found in handle
# >>> Not found in NCBI_PROT, will now search gramene
# failed for: MLOC_12359.2 No records found in handle
# >>> Not found in gramene, will now search RAP
# failed for: MLOC_12359.2 list index out of range
#
# >>> Searching Item 3 out of 11844.
# > Will now search Uniprot
# ...
